# %%
import pandas as pd

# %%
data=pd.read_excel('Apriori.xlsx')

# %%
data.columns=data.columns.str.strip().str.replace(' ','_')

# %%
data.Bill_Number.nunique()
# Out:
# 69982

# %%
basket=data.pivot_table(index='Bill_Number',
                       columns='Item_Desc',
                       values='Quantity',
                        aggfunc='sum',
                        fill_value=0)
basket.head()
# Out:
# Item_Desc    1 AXE TWIST                     1+1 BTL4 SEASON WHITE           \
# Bill_Number
# G0470109                                  0                               0
# G0470110                                  0                               0
# G0470111                                  0                               0
# G0470112                                  0                               0
# G0470113                                  0                               0
#
# Item_Desc    1+1 GLS 4SEASON RED             1+1 GLS 4SEASONS WHITE          \
# Bill_Number
# G0470109                                  0                               0
# G0470110                                  0                               0
# G0470111                                  0                               0
# G0470112                                  0                               0
# G0470113                                  0                               0
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
data.Item_Desc.value_counts()[:20].plot.bar()
plt.show()

# %%
def encode(x):
    if x>=1: return 1
    elif x<=0: return 0

# %%
basket_sets=basket.applymap(encode)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
frequent_item_sets=apriori(basket_sets,min_support=.0001,use_colnames=True)
